# %% [markdown]
# # Estudio de caso de Cardio Good Fitness
#
#      Al equipo de investigación de mercado de AdRight se le asigna la tarea de identificar el perfil del cliente típico para cada producto de cinta de correr ofrecido por CardioGood Fitness.
#
#      El equipo de investigación de mercado decide investigar si existen diferencias entre las líneas de productos con respecto a las características del cliente.
#
#      El equipo decide recopilar datos sobre las personas que compraron una caminadora en una tienda minorista de CardioGoodFitness durante los tres meses anteriores.
#
#      Los datos se almacenan en el archivo CardioGoodFitness.csv
#
# ## El equipo identifica las siguientes variables del cliente para estudiar:
#
#      producto comprado, TM195, TM498 o TM798
#      género;
#      edad en años;
#      educación, en años;
#      estado civil, soltero o en pareja;
#      Ingreso Anual del Hogar ;
#      número promedio de veces que el cliente planea usar la caminadora cada semana;
#      número promedio de millas que el cliente espera caminar/correr cada semana;
#      y autoevaluación del estado físico en una escala del 1 al 5, donde 1 es mala forma física y 5 es excelente forma física.

# %% [markdown]
# ### Import de librerias

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style(rc = {'axes.facecolor': 'grey'})

# %%
df = pd.read_csv('CardioGoodFitness.csv')
df.sort_values(by=['Age']).head(30)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 3     TM195   19    Male         12        Single      3        3   32973
# 80    TM498   19    Male         14        Single      3        3   31836
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 4     TM195   20    Male         13     Partnered      4        2   35247
# 5     TM195   20  Female         14     Partnered      3        3   32973
# 82    TM498   20  Female         14     Partnered      3        3   34110
# 83    TM498   20    Male         14        Single      3        3   38658
# 81    TM498   20    Male         14        Single      2        3   32973
# 6     TM195   21  Female         14     Partnered      3        3   35247
# 7     TM195   21    Male         13        Single      3        3   32973
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.shape
# Out:
# (180, 9)

# %% [markdown]
# Revision de valores nulos

# %%
df.isna().any()
# Out:
# Product          False
# Age              False
# Gender           False
# Education        False
# MaritalStatus    False
# Usage            False
# Fitness          False
# Income           False
# Miles            False
# dtype: bool

# %%
df.describe(include='all')
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
df.Age.median()
# Out:
# 26.0

# %% [markdown]
# ### Histogramas

# %%
df[df.Age == 27]
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 41    TM195   27  Female         14     Partnered      3        2   45480
# 42    TM195   27    Male         16        Single      4        3   54576
# 43    TM195   27  Female         14     Partnered      2        3   45480
# 111   TM498   27    Male         14        Single      4        2   45480
# 159   TM798   27    Male         16     Partnered      4        5   83416
# 160   TM798   27    Male         18        Single      4        3   88396
# 161   TM798   27    Male         21     Partnered      4        4   90886
#
#      Miles
# 41      66
# 42      85
# 43      56
# 111     53
# 159    160
# 160    100
# 161    100

# %%
df.hist(figsize=(20,20), bins=10)
# Out:
# array([[<AxesSubplot: title={'center': 'Age'}>,
#         <AxesSubplot: title={'center': 'Education'}>],
#        [<AxesSubplot: title={'center': 'Usage'}>,
#         <AxesSubplot: title={'center': 'Fitness'}>],
#        [<AxesSubplot: title={'center': 'Income'}>,
#         <AxesSubplot: title={'center': 'Miles'}>]], dtype=object)

# %% [markdown]
# ### Diagramas de caja
# Cual es el modelo mas popular por género?

# %%
pd.crosstab(df['Product'], df['Gender'] )
# Out:
# Gender   Female  Male
# Product
# TM195        40    40
# TM498        29    31
# TM798         7    33

# %%
sns.boxenplot(x='Gender',y='Age',data=df)
# Out:
# <AxesSubplot: xlabel='Gender', ylabel='Age'>

# %% [markdown]
# Promedio de cada variable para hombres

# %%
df[df.Gender == 'Male'].median(numeric_only=True))
# Out:
#   Cell In[22], line 1
#     df[df.Gender == 'Male'].median(numeric_only=True))
#                                                      ^
# SyntaxError: unmatched ')'

# %%
pd.crosstab(df['Product'], df['MaritalStatus'] )
# Out:
# MaritalStatus  Partnered  Single
# Product
# TM195                 48      32
# TM498                 36      24
# TM798                 23      17

# %%
df.hist(by='Gender', column='Income', bins=20)
# Out:
# array([<AxesSubplot: title={'center': 'Female'}>,
#        <AxesSubplot: title={'center': 'Male'}>], dtype=object)

# %% [markdown]
# Promedio de edad

# %%
df.Age.mean()
# Out:
# 28.788888888888888

# %% [markdown]
# ### Distribucion de edades

# %%
sns.displot(df['Age'], kind='kde')

# %% [markdown]
# ### Cantidad de compradores por genero

# %%
sns.countplot(x='Product', hue='Gender', data=df, palette=['#0081B4', '#FAD3E7'])
# Out:
# <AxesSubplot: xlabel='Product', ylabel='count'>

# %%
sns.pairplot(df)

# %% [markdown]
# ### Mapa de correlacion

# %%
corr = df.corr(numeric_only=True)
corr
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %% [markdown]
# ### Mapa de Calor

# %%
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Como afectan los ingresos y la edad a la desicion de que modelo comprar?
# Podemos concluir que el modelo TM798 es el mas caro

# %% [markdown]
# Promedio de las edades de la gente que compro el modelo de mejor categoria.

# %%
df[df.Product == 'TM798'].mean(numeric_only=True)
# Out:
# Age             29.100
# Education       17.325
# Usage            4.775
# Fitness          4.625
# Income       75441.575
# Miles          166.900
# dtype: float64
